# %%
from kafka import KafkaConsumer
from json import loads

consumer = KafkaConsumer(
    'iabd-topic',
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    group_id='iabd-grupo-1',
    value_deserializer=lambda m: loads(m.decode('utf-8')),
    bootstrap_servers=['10.133.29.116:9092'])

for m in consumer:
    print(m.value)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#       2 from json import loads
#       4 consumer = KafkaConsumer(
#       5     'iabd-topic',
#       6     auto_offset_reset='earliest',
#    (...)
#       9     value_deserializer=lambda m: loads(m.decode('utf-8')),
#      10     bootstrap_servers=['10.133.29.116:9092'])
# ---> 12 for m in consumer:
#      13     print(m.value)
#
# File c:\Users\oscar.torresrodrigue\AppData\Local\miniconda3\envs\bigdata\lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File c:\Users\oscar.torresrodrigue\AppData\Local\miniconda3\envs\bigdata\lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File c:\Users\oscar.torresrodrigue\AppData\Local\miniconda3\envs\bigdata\lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File c:\Users\oscar.torresrodrigue\AppData\Local\miniconda3\envs\bigdata\lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File c:\Users\oscar.torresrodrigue\AppData\Local\miniconda3\envs\bigdata\lib\site-packages\kafka\consumer\group.py:675, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     665 def _poll_once(self, timeout_ms, max_records, update_offsets=True):
#     666     """Do one round of polling. In addition to checking for new data, this does
#     667     any needed heart-beating, auto-commits, and offset updates.
#     668
#    (...)
#     673         dict: Map of topic to list of records (may be empty).
#     674     """
# --> 675     self._coordinator.poll()
#     677     # Fetch positions if we have partitions we're subscribed to that we
#     678     # don't know the offset for
#     679     if not self._subscription.has_all_fetch_positions():
#
# File c:\Users\oscar.torresrodrigue\AppData\Local\miniconda3\envs\bigdata\lib\site-packages\kafka\coordinator\consumer.py:289, in ConsumerCoordinator.poll(self)
#     286             metadata_update = self._client.cluster.request_update()
#     287             self._client.poll(future=metadata_update)
# --> 289         self.ensure_active_group()
#     291     self.poll_heartbeat()
#     293 self._maybe_auto_commit_offsets_async()
#
# File c:\Users\oscar.torresrodrigue\AppData\Local\miniconda3\envs\bigdata\lib\site-packages\kafka\coordinator\base.py:353, in BaseCoordinator.ensure_active_group(self)
#     350     self._start_heartbeat_thread()
#     352 while self.need_rejoin() or self._rejoin_incomplete():
# --> 353     self.ensure_coordinator_ready()
#     355     # call on_join_prepare if needed. We set a flag
#     356     # to make sure that we do not call it a second
#     357     # time if the client is woken up before a pending
#    (...)
#     361     # changes the matched subscription set) can occur
#     362     # while another rebalance is still in progress.
#     363     if not self.rejoining:
#
# File c:\Users\oscar.torresrodrigue\AppData\Local\miniconda3\envs\bigdata\lib\site-packages\kafka\coordinator\base.py:267, in BaseCoordinator.ensure_coordinator_ready(self)
#     265         self._client.poll(future=metadata_update)
#     266     else:
# --> 267         time.sleep(self.config['retry_backoff_ms'] / 1000)
#     268 else:
#     269     raise future.exception
#
# KeyboardInterrupt:
