# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
def cargaAlcaldes(archivo, columna, fila, cabecera, nombreHoja):
    return pd.read_excel(archivo, sheet_name=nombreHoja,
         names=cabecera, usecols=columna, skiprows=fila)

directorio = "/Users/oscar.torresrodrigue/Downloads/alcaldes/"
nombre_archivos = [ [directorio + "Alcaldes_Mandato_1979_1983.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 1979-1983'],
                    [directorio + "Alcaldes_Mandato_1983_1987.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 1983-1987'],
                    [directorio + "Alcaldes_Mandato_1987_1991.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 1987-1991'],
                    [directorio + "Alcaldes_Mandato_1991_1995.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 1991-1995'],
                    [directorio + "Alcaldes_Mandato_1995_1999.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 1995-1999'],
                    [directorio + "Alcaldes_Mandato_1999_2003.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 1999-2003'],
                    [directorio + "Alcaldes_Mandato_2003_2007.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 2003-2007'],
                    [directorio + "Alcaldes_Mandato_2007_2011.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 2007-2011'],
                    [directorio + "Alcaldes_Mandato_2011_2015.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 2011-2015'],
                    [directorio + "Alcaldes_Mandato_2015_2019.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 2015-2019'],
                    [directorio + "Alcaldes_Mandato_2019_2023.xlsx", "D:K", 8, 
                     ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CÓDIGO', 'NOMBRE', 'LISTA', 'FECHA-POSESION', 'FECHA-BAJA'], 'Alcaldes 2015-2019']
                    ]


#Inicialización do dataframe vacío
dfAlcaldes = pd.DataFrame([])

for i in range(0, len(nombre_archivos)):
    dfAlcaldes = pd.concat([dfAlcaldes,
        cargaAlcaldes(nombre_archivos[i][0], nombre_archivos[i][1], 
            nombre_archivos[i][2], nombre_archivos[i][3], nombre_archivos[i][4])]
    )

dfAlcaldes
# Out:
#            CCAA  PROVINCIA           MUNICIPIO  CÓDIGO  \
# 0     Andalucía    Almería            ABRUCENA  040025
# 1     Andalucía    Almería                ADRA  040031
# 2     Andalucía    Almería           ALBANCHEZ  040046
# 3     Andalucía    Almería           ALBOLODUY  040059
# 4     Andalucía    Almería               ALBOX  040062
# ...         ...        ...                 ...     ...
# 8758  Rioja, La  Rioja, La   Viniegra de Abajo  261780
# 8759  Rioja, La  Rioja, La  Viniegra de Arriba  261793
# 8760  Rioja, La  Rioja, La            Zarratón  261807
# 8761  Rioja, La  Rioja, La             Zarzosa  261814
# 8762  Rioja, La  Rioja, La           Zorraquín  261835
#
#                                NOMBRE  LISTA       FECHA-POSESION FECHA-BAJA
# 0                  MARTINEZ LAO, JUAN   PSOE  1979-04-19 00:00:00        NaT
# 1             SARMIENTO POSADA, PEDRO  OTROS  1979-04-19 00:00:00        NaT
# ...
