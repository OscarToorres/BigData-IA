# %%
import pandas as pd

# %%
df = pd.read_csv("inflacion_por_pais_1960-2022.csv")
df
# Out:
#         Country Name Country Code                              Indicator Name  \
# 0              Aruba          ABW  Inflación, precios al consumidor (% anual)
# 1                NaN          AFE  Inflación, precios al consumidor (% anual)
# 2         Afganistán          AFG  Inflación, precios al consumidor (% anual)
# 3                NaN          AFW  Inflación, precios al consumidor (% anual)
# 4             Angola          AGO  Inflación, precios al consumidor (% anual)
# ..               ...          ...                                         ...
# 261           Kosovo          XKX  Inflación, precios al consumidor (% anual)
# 262  Yemen, Rep. del          YEM  Inflación, precios al consumidor (% anual)
# 263        Sudáfrica          ZAF  Inflación, precios al consumidor (% anual)
# 264           Zambia          ZMB  Inflación, precios al consumidor (% anual)
# 265         Zimbabwe          ZWE  Inflación, precios al consumidor (% anual)
#
# ...

# %% [markdown]
# ### Recorrer cada pais para saber desde que año tenemos datos sobre la inflacion para todos los paises

# %%
df_s = pd.read_csv("salario_medio.csv")
df_s.columns
# Out:
# Index(['Unnamed: 0', 'fecha', 'salario medio (€)', 'pais'], dtype='object')

# %%
df_s.groupby("pais").all()
# Out:
#                 Unnamed: 0  fecha  salario medio (€)
# pais
# Alemania              True   True               True
# Australia             True   True               True
# Austria               True   True               True
# Bulgaria              True   True               True
# Bélgica               True   True               True
# Canadá                True   True               True
# Chequia               True   True               True
# Chile                 True   True               True
# Chipre                True   True               True
# Colombia              True   True               True
# Corea del Sur         True   True               True
# Costa Rica            True   True               True
# Croacia               True   True               True
# Dinamarca             True   True               True
# Eslovaquia            True   True               True
# Eslovenia             True   True               True
# España               False   True               True
# ...

# %%
df_s.groupby(by=["pais"])

# %%
# Ya esta modificado con los nombres cambiados del otro dataset
nombre_paises = ["Alemania", "Australia", "Austria", "Bulgaria", "Bélgica", "Canadá", "República Checa", "Chile", "Chipre", 
                 "Colombia", "Corea del Sur" , "Costa Rica", "Croacia", "Dinamarca", "Eslovaquia", "Eslovenia", 
                 "España", "Estados Unidos", "Estonia", "Finlandia", "Francia", "Grecia", "Hungría", "Irlanda", 
                 "Islandia", "Israel", "Italia", "Japón",  "Letonia", "Lituania", "Luxemburgo", "Malta", "México", 
                 "Noruega", "Nueva Zelandia", "Países Bajos", "Polonia", "Portugal", "Reino Unido", "Rumania", "Suecia", 
                 "Suiza", "Turquía"]

# %%
contador = 0
for name in df["Country Name"]:
    if (nombre_paises.__contains__(name)):
        # nombre_paises.remove(name)
        print(f"Nombre en df: {name}  Nombre_paises: {nombre_paises[contador]}")
        contador += 1

print(contador)
# Out:
# 0

# %%
nombre_paises
# Chequia -> República Checa
# Corea del Sur -> Corea, República de
# Eslovaquia -> República Eslovaca
# Nueva Zelanda -> Nueva Zelandia
# Rumanía -> Rumania
# Türkiye -> Turquía
# Out:
# ['Chequia',
#  'Corea del Sur',
#  'Eslovaquia',
#  'Nueva Zelanda',
#  'Rumanía',
#  'Türkiye']
