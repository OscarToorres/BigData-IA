# %% [markdown]
# # T2.1: Exercicio CSV con PANDAS

# %%
#Importar librerias necesarias
import pandas as pd
import os
import tempfile

# %%
#https://realpython.com/pandas-merge-join-and-concat/
#obtener los archivos *.csv de nuestro dispositivo
path_base = "C:/Users/oscar.torresrodrigue/Downloads/"
#path_base = "C:\\Users\\oscar.torresrodrigue\\Downloads\\" Con las dos barras tambien funciona pero no es recomendable
#path_base = "/Users/oscar.torresrodrigue/Downloads/" Con la barra del principio sola, indica en la unidad que esté

os.path.join(path_base,"a_coruna.csv")

dfCoruna = pd.read_csv(f"{path_base}location.json")
# dfLugo = pd.read_csv(path_base + "lugo.csv")
# dfOurense = pd.read_csv(os.path.join(path_base,"ourense.csv"))
# dfPontevedra = pd.read_csv(path_base+"pontevedra.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 path_base = "C:/Users/oscar.torresrodrigue/Downloads/"
#       4 #path_base = "C:\\Users\\oscar.torresrodrigue\\Downloads\\" Con las dos barras tambien funciona pero no es recomendable
#       5 #path_base = "/Users/oscar.torresrodrigue/Downloads/" Con la barra del principio sola, indica en la unidad que esté
# ----> 7 os.path.join(path_base,"a_coruna.csv")
#       9 dfCoruna = pd.read_csv(f"{path_base}location.json")
#
# NameError: name 'os' is not defined

# %%
dfTotal = pd.concat([dfCoruna,dfLugo,dfOurense,dfPontevedra])

# %%
arquivo_temporal = os.path.join("C:\\Users\\oscar.torresrodrigue\\AppData\\Local\\Temp\\temporal.csv")
print(arquivo_temporal)
dfTotal.to_csv(arquivo_temporal)
# Out:
# C:\Users\oscar.torresrodrigue\AppData\Local\Temp\temporal.csv

# %%
df = dfTotal
df
# Out:
#        Código                                               Nome  \
# 0    15000016                        CEIP Plurilingüe San Marcos
# 1    15000107                                        CEIP A Maía
# 2    15000132                               CPR Plurilingüe Alca
# 3    15000338                                    CPI As Mirandas
# 4    15000363                              CEIP Ponte dos Brozos
# ..        ...                                                ...
# 611  36025189  EMUSPR Escola de Música da Banda Unión Musical...
# 612  36025190    EMUSPR Escola da Banda de Música Popular de Tui
# 613  36025207  EMUSPR Escola de Música Lira de San Miguel de Oia
# 614  36025219              Cen. Pub. Escola de Canteiros de Poio
# 615  36025220                                   CAD FDYE-Galicia
#
#                                  Enderezo          Concello   Provincia  \
# 0                      Campo da Feira s/n          Abegondo    A Coruña
# ...

# %%
df.head()
# Out:
#      Código                         Nome  \
# 0  15000016  CEIP Plurilingüe San Marcos
# 1  15000107                  CEIP A Maía
# 2  15000132         CPR Plurilingüe Alca
# 3  15000338              CPI As Mirandas
# 4  15000363        CEIP Ponte dos Brozos
#
#                                Enderezo  Concello Provincia  Cód. postal  \
# 0                    Campo da Feira s/n  Abegondo  A Coruña      15318.0
# 1      Rúa Peregrina, s/n (Bertamiráns)      Ames  A Coruña      15220.0
# 2            Lugar Biduído de Arriba 36      Ames  A Coruña      15895.0
# 3       Avenida Celso Emilio Ferreiro 4      Ares  A Coruña      15624.0
# 4  Avenida Arsenio Iglesias, 34 (Sabon)   Arteixo  A Coruña      15142.0
#
#     Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y TITULARIDADE  \
# 0  881880201           CEIP     43.229183     -8.286580      Pública
# 1  881866002           CEIP     42.867485     -8.657342      Pública
# ...

# %%
df.tail()
# Out:
#        Código                                               Nome  \
# 611  36025189  EMUSPR Escola de Música da Banda Unión Musical...
# 612  36025190    EMUSPR Escola da Banda de Música Popular de Tui
# 613  36025207  EMUSPR Escola de Música Lira de San Miguel de Oia
# 614  36025219              Cen. Pub. Escola de Canteiros de Poio
# 615  36025220                                   CAD FDYE-Galicia
#
#                       Enderezo          Concello   Provincia  Cód. postal  \
# 611  Lugar Lugar de Covas 14 B  Cerdedo-Cotobade  Pontevedra      36120.0
# 612          Lugar Gándara s/n               Tui  Pontevedra      36720.0
# 613        Camiño de Currás 34              Vigo  Pontevedra      36390.0
# 614        Rúa Illa do Santo 2              Poio  Pontevedra      36005.0
# 615    Avenida das Camelias 53              Vigo  Pontevedra      36211.0
#
#       Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y TITULARIDADE  \
# ...

# %%
df.shape
# Out:
# (1641, 13)

# %%
df.describe()
# Out:
#              Código   Cód. postal  COORDENADA_X  COORDENADA_Y
# count  1.641000e+03   1640.000000   1641.000000   1641.000000
# mean   2.656453e+07  26990.679268     39.940281     -5.742280
# std    9.288248e+06   9306.468180     11.563759     11.133819
# min    1.500002e+07  15001.000000    -13.488744     -9.269669
# 25%    1.502624e+07  15701.000000     42.241528     -8.701391
# 50%    2.702094e+07  27875.000000     42.587135     -8.425463
# 75%    3.601112e+07  36214.000000     43.108734     -7.862472
# max    3.602522e+07  36995.000000     43.738419     43.741764

# %%
df['Concello']
# Out:
# 0              Abegondo
# 1                  Ames
# 2                  Ames
# 3                  Ares
# 4               Arteixo
#              ...
# 611    Cerdedo-Cotobade
# 612                 Tui
# 613                Vigo
# 614                Poio
# 615                Vigo
# Name: Concello, Length: 1641, dtype: object

# %%
type(df['Concello'])
# Out:
# pandas.core.series.Series

# %%
df.TITULARIDADE
# Out:
# 0      Pública
# 1      Pública
# 2      Privada
# 3      Pública
# 4      Pública
#         ...
# 611    Privada
# 612    Privada
# 613    Privada
# 614    Pública
# 615    Privada
# Name: TITULARIDADE, Length: 1641, dtype: object

# %%
type(df.Concello)
# Out:
# pandas.core.series.Series

# %%
df[['Nome']]
# Out:
#                                                   Nome
# 0                          CEIP Plurilingüe San Marcos
# 1                                          CEIP A Maía
# 2                                 CPR Plurilingüe Alca
# 3                                      CPI As Mirandas
# 4                                CEIP Ponte dos Brozos
# ..                                                 ...
# 611  EMUSPR Escola de Música da Banda Unión Musical...
# 612    EMUSPR Escola da Banda de Música Popular de Tui
# 613  EMUSPR Escola de Música Lira de San Miguel de Oia
# 614              Cen. Pub. Escola de Canteiros de Poio
# 615                                   CAD FDYE-Galicia
#
# [1641 rows x 1 columns]

# %%
type(df[['Nome']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Código','Nome']]
# Out:
#        Código                                               Nome
# 0    15000016                        CEIP Plurilingüe San Marcos
# 1    15000107                                        CEIP A Maía
# 2    15000132                               CPR Plurilingüe Alca
# 3    15000338                                    CPI As Mirandas
# 4    15000363                              CEIP Ponte dos Brozos
# ..        ...                                                ...
# 611  36025189  EMUSPR Escola de Música da Banda Unión Musical...
# 612  36025190    EMUSPR Escola da Banda de Música Popular de Tui
# 613  36025207  EMUSPR Escola de Música Lira de San Miguel de Oia
# 614  36025219              Cen. Pub. Escola de Canteiros de Poio
# 615  36025220                                   CAD FDYE-Galicia
#
# [1641 rows x 2 columns]

# %%
type(df[['Código','Nome']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(['Código','Nome'])
# Out:
# list

# %% [markdown]
# ### Seleccionar centros que sexan de titularidade privada. Cantos hai?

# %%
dfTit = df[df["TITULARIDADE"] == "Privada"]
dfTit.shape[0]
dfTit
# Out:
#        Código                                               Nome  \
# 2    15000132                               CPR Plurilingüe Alca
# 5    15000545                               EMUSPR Presto Vivace
# 7    15000600             CPR Plurilingüe Ntra. Sra. del Rosario
# 11   15001112          CPR Plurilingüe Nuestra Señora del Carmen
# 15   15001151                                    EMUSPR de Vedra
# ..        ...                                                ...
# 610  36025177           CPR Fundación Laboral de la Construcción
# 611  36025189  EMUSPR Escola de Música da Banda Unión Musical...
# 612  36025190    EMUSPR Escola da Banda de Música Popular de Tui
# 613  36025207  EMUSPR Escola de Música Lira de San Miguel de Oia
# 615  36025220                                   CAD FDYE-Galicia
#
#                        Enderezo          Concello   Provincia  Cód. postal  \
# 2    Lugar Biduído de Arriba 36              Ames    A Coruña      15895.0
# ...

# %% [markdown]
# ### Seleccionar centros que teñan ensinanzas concertados. Cantos hai?

# %%
dfEnCon = df[df["ENSINO_CONCERTADO"] != "Non"]
dfEnCon.shape[0]
dfEnCon
# Out:
#        Código                                       Nome  \
# 2    15000132                       CPR Plurilingüe Alca
# 7    15000600     CPR Plurilingüe Ntra. Sra. del Rosario
# 11   15001112  CPR Plurilingüe Nuestra Señora del Carmen
# 30   15002566                      CPR Plurilingüe Artai
# 39   15003200         CPR Plurilingüe Manuela Rial Mouzo
# ..        ...                                        ...
# 488  36020155                                CPR Estudio
# 515  36024057                 CPR Plurilingüe Bouza Brey
# 555  36024574                     CEEPR Princesa Letizia
# 603  36025104                       CEEPR Amencer-Aspace
# 609  36025165                        CPR FP Montecastelo
#
#                                            Enderezo              Concello  \
# 2                        Lugar Biduído de Arriba 36                  Ames
# 7                                     Rúa Carmen 22                 Arzúa
# ...

# %% [markdown]
# ### Hai algún centro con ensinanzas concertadas dependente da Consellería?

# %%
dfEnConDep = df[(df["ENSINO_CONCERTADO"] != "Non") & (df["DEPENDENTE"] != "Non")]
dfEnCon
# Out:
# Empty DataFrame
# Columns: [Código, Nome, Enderezo, Concello, Provincia, Cód. postal, Teléfono, Tipo de centro, COORDENADA_X, COORDENADA_Y, TITULARIDADE, ENSINO_CONCERTADO, DEPENDENTE]
# Index: []

# %% [markdown]
# ### Seleccionar centros de titularidade pública de Coruña. Cantos hai?

# %%
df[(df["TITULARIDADE"] == "Pública") & (df["Provincia"] == "A Coruña")]
# Out:
#        Código                            Nome  \
# 0    15000016     CEIP Plurilingüe San Marcos
# 1    15000107                     CEIP A Maía
# 3    15000338                 CPI As Mirandas
# 4    15000363           CEIP Ponte dos Brozos
# 6    15000569           CEIP San Xosé Obreiro
# ..        ...                             ...
# 586  15033113          ESMU Municipal de Ames
# 589  15033149  CEIP Plurilingüe Vila de Rutis
# 591  15033162      ESMU Municipal de Negreira
# 594  15033198                CRA A Tarandeira
# 597  15033228   CEIP Plurilingüe Novo Mesoiro
#
#                                               Enderezo    Concello Provincia  \
# 0                                   Campo da Feira s/n    Abegondo  A Coruña
# 1                     Rúa Peregrina, s/n (Bertamiráns)        Ames  A Coruña
# 3                      Avenida Celso Emilio Ferreiro 4        Ares  A Coruña
# 4                 Avenida Arsenio Iglesias, 34 (Sabon)     Arteixo  A Coruña
# ...

# %% [markdown]
# ### Seleccionar centros de titularidade pública de Lugo. Cantos hai?

# %%
df[(df["TITULARIDADE"] == "Pública") & (df["Provincia"] == "Lugo")]
# Out:
#        Código                                   Nome  \
# 0    27000010         CEIP Aquilino Iglesia Alvariño
# 1    27000198      CEIP Plurilingüe de Antas de Ulla
# 2    27000319  CEIP Plurilingüe Concepción López Rey
# 3    27000541  CEIP San Miguel de Reinante Barreiros
# 4    27000617                       CFEA de Becerreá
# ..        ...                                    ...
# 215  27020938                 ESMU Municipal de Lugo
# 216  27020941           ESMU Municipal de Monterroso
# 217  27020951              ESMU Municipal de Begonte
# 218  27020963       ESMU Municipal de Outeiro de Rei
# 224  27601509                         EPAPU Albeiros
#
#                                  Enderezo        Concello Provincia  \
# 0                   Praza do Concello s/n          Abadín      Lugo
# 1             Rúa Miguel Ángel Blanco s/n   Antas de Ulla      Lugo
# 2     Rúa Doutor Nogueira, s/n (O Cadavo)         Baleira      Lugo
# ...

# %% [markdown]
# ### Seleccionar centros de titularidade pública de Ourense. Cantos hai?

# %%
df[(df["TITULARIDADE"] == "Pública") & (df["Provincia"] == "Ourense")]
# Out:
#        Código                                   Nome  \
# 0    32000058                      CEIP Padre Feijoo
# 1    32000101              ESMU Municipal de Allariz
# 2    32000113            ESMU Municipal de Ribadavia
# 3    32000356   CEIP Plurilingüe Ramón Otero Pedrayo
# 4    32000708                CEIP Virxe de Guadalupe
# ..        ...                                    ...
# 178  32020768  ESMU Municipal do Barco de Valdeorras
# 179  32020771             EPAPU de Pereiro de Aguiar
# 180  32020781           CEIP Plurilingüe O Ruxidoiro
# 182  32020801                       CRA de Monterrei
# 193  32020926              ESMU do Concello de Coles
#
#                           Enderezo               Concello Provincia  \
# 0         Estrada de Xunqueira s/n                Allariz   Ourense
# 1                    Praza Maior 1                Allariz   Ourense
# 2                Rúa Redondela s/n              Ribadavia   Ourense
# ...

# %% [markdown]
# ### Seleccionar centros de titularidade pública de Pontevedra. Cantos hai?

# %%
df[(df["TITULARIDADE"] == "Pública") & (df["Provincia"] == "Pontevedra")]
# Out:
#        Código                                   Nome  \
# 0    36000031                CEIP Antonio Carpintero
# 1    36000181                       CEIP Amor Ruibal
# 2    36000247                    CPI de Cova Terreña
# 3    36000302                         CEP de Sabarís
# 4    36000326            CEIP Plurilingüe Montemogos
# ..        ...                                    ...
# 588  36024938                  CRA de Caldas de Reis
# 590  36024951     Cen. Pub. Escola Galega do Deporte
# 593  36024987                      IES de Soutomaior
# 596  36025013            CEIP Manuel Padín Truiteiro
# 614  36025219  Cen. Pub. Escola de Canteiros de Poio
#
#                                  Enderezo        Concello   Provincia  \
# 0    Rúa Miguel Davila, s/n (Consistorio)            Arbo  Pontevedra
# 1                Perdecanai (Santa María)           Barro  Pontevedra
# 2                      Dolores Agrelo s/n          Baiona  Pontevedra
# ...

# %% [markdown]
# ### Seleccionar centros de tipo: CIFP de cada unha das catro provincias. Cantos hai?

# %%
dfC = df[(df["Tipo de centro"] == "CIFP") & (df["Provincia"] == "A Coruña")]
dfL = df[(df["Tipo de centro"] == "CIFP") & (df["Provincia"] == "Lugo")]
dfP = df[(df["Tipo de centro"] == "CIFP") & (df["Provincia"] == "Pontevedra")]
dfO = df[(df["Tipo de centro"] == "CIFP") & (df["Provincia"] == "Ourense")]

print("Coruña", dfC.shape[0])
print("Lugo", dfL.shape[0])
print("Pontevedra", dfP.shape[0])
print("Ourense", dfO.shape[0])
# Out:
# Coruña 13
# Lugo 3
# Pontevedra 9
# Ourense 5

# %% [markdown]
# ### Seleccionar centros de tipo: CPI, CEIP e IES de cada unha das catro provincias. Cantos hai?

# %%
dfC = df[(df["Tipo de centro"] == "CPI") | (df["Tipo de centro"] == "IES") | (df["Tipo de centro"] == "CIFP") & (df["Provincia"] == "A Coruña")]
dfP = df[(df["Tipo de centro"] == "CPI") | (df["Tipo de centro"] == "IES") | (df["Tipo de centro"] == "CIFP") & (df["Provincia"] == "Pontevedra")]
dfL = df[(df["Tipo de centro"] == "CPI") | (df["Tipo de centro"] == "IES") | (df["Tipo de centro"] == "CIFP") & (df["Provincia"] == "Lugo")]
dfO = df[(df["Tipo de centro"] == "CPI") | (df["Tipo de centro"] == "IES") | (df["Tipo de centro"] == "CIFP") & (df["Provincia"] == "Ourense")]

df["Tipo de centro"]

print("Coruña", dfC.shape[0])
print("Lugo", dfL.shape[0])
print("Pontevedra", dfP.shape[0])
print("Ourense", dfO.shape[0])
# Out:
# Coruña 324
# Lugo 314
# Pontevedra 320
# Ourense 316

# %% [markdown]
# ### Seleccionar o número de centros por concello.

# %%
dfCentroConcello = df.groupby(['Concello','Tipo de centro']).count()
dfCentroConcello
# Out:
#                                    Código  Nome  Enderezo  Provincia  \
# Concello           Tipo de centro
# A Arnoia           CEIP                 1     1         1          1
# A Baña             CPI                  1     1         1          1
#                    ESMU                 1     1         1          1
# A Capela           CEIP                 1     1         1          1
# A Cañiza           CEIP                 1     1         1          1
# ...                                   ...   ...       ...        ...
# Xove               IES                  1     1         1          1
# Xunqueira de Ambía CEIP                 1     1         1          1
# Zas                CEIP                 1     1         1          1
#                    CPI                  1     1         1          1
#                    IES                  1     1         1          1
#
#                                    Cód. postal  Teléfono  COORDENADA_X  \
# ...

# %% [markdown]
# ### Seleccionar o número de centros de cada tipo por concello.

# %%
dfCentroTipo=df[['Tipo de centro', 'Concello', 'Nome']]
dfCentroTipo = dfCentroTipo.groupby(['Concello','Tipo de centro']).count()
dfCentroTipo
# Out:
#                                    Nome
# Concello           Tipo de centro
# A Arnoia           CEIP               1
# A Baña             CPI                1
#                    ESMU               1
# A Capela           CEIP               1
# A Cañiza           CEIP               1
# ...                                 ...
# Xove               IES                1
# Xunqueira de Ambía CEIP               1
# Zas                CEIP               1
#                    CPI                1
#                    IES                1
#
# [864 rows x 1 columns]

# %% [markdown]
# ### Limpando datos con erros: Dime qué podes limpar e como nestes datos.

# %%
dfFiltrado = df.fillna(0)
dfFiltrado = dfFiltrado.rename(columns={"Cód. postal":"CódPostal"})
dfFiltrado = dfFiltrado.rename(columns={"Tipo de centro":"TipoCentro"})
dfFiltrado["Teléfono"] = dfFiltrado.to_string(columns={"Teléfono"})
dfFiltrado
# Out:
#        Código                                               Nome  \
# 0    15000016                        CEIP Plurilingüe San Marcos
# 1    15000107                                        CEIP A Maía
# 2    15000132                               CPR Plurilingüe Alca
# 3    15000338                                    CPI As Mirandas
# 4    15000363                              CEIP Ponte dos Brozos
# ..        ...                                                ...
# 611  36025189  EMUSPR Escola de Música da Banda Unión Musical...
# 612  36025190    EMUSPR Escola da Banda de Música Popular de Tui
# 613  36025207  EMUSPR Escola de Música Lira de San Miguel de Oia
# 614  36025219              Cen. Pub. Escola de Canteiros de Poio
# 615  36025220                                   CAD FDYE-Galicia
#
#                                  Enderezo          Concello   Provincia  \
# 0                      Campo da Feira s/n          Abegondo    A Coruña
# ...

# %% [markdown]
# ### Garda o dataframe total resultante nos seguintes formatos (e logo volve abrilo nese formato e mostra a cabeceira):

# %% [markdown]
# ### CSV

# %%
arquivo_temporal_csv = os.path.join("C:\\Users\\oscar.torresrodrigue\\AppData\\Local\\Temp\\temporalcsv.csv")
dfFiltrado.to_csv(arquivo_temporal_csv)

# %% [markdown]
# ### Excel

# %%
arquivo_temporal_excel = os.path.join("C:\\Users\\oscar.torresrodrigue\\AppData\\Local\\Temp\\temporalexcel.xlsx")
dfFiltrado.to_excel(arquivo_temporal_excel)

# %% [markdown]
# ### JSON: Coidado cos índices se xuntaches os dataframes

# %%
arquivo_temporal_json = os.path.join("C:\\Users\\oscar.torresrodrigue\\AppData\\Local\\Temp\\temporaljson.json")
dfFiltradoo = dfFiltrado.reset_index(drop=True)
dfFiltradoo.to_json(arquivo_temporal_json)

# %% [markdown]
# ### XML

# %%
arquivo_temporal_xml = os.path.join("C:\\Users\\oscar.torresrodrigue\\AppData\\Local\\Temp\\temporalxml.xml")
dfFiltrado.to_xml(arquivo_temporal_xml)

# %% [markdown]
# ### PARQUET

# %%
arquivo_temporal_parquet = os.path.join("C:\\Users\\oscar.torresrodrigue\\AppData\\Local\\Temp\\temporalparquet.parquet")
dfFiltrado.to_parquet(arquivo_temporal_parquet)

# %% [markdown]
# ### Archivos generados

# %% [markdown]
# ![image.png](attachment:image.png)
